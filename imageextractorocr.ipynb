# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
#IMAGE_PATH = '/Users/diyabasu/Development/pdf whisperer/vitcatalog2.jpeg'
IMAGE_PATH='/Users/diyabasu/Development/pdf whisperer/Screenshot 2023-09-20 at 12.29.19 PM.png'

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(IMAGE_PATH)
result
# Out:
# [([[496, 210], [1174, 210], [1174, 262], [496, 262]],
#   'INVENTIVE DISCLOSURE',
#   0.8992672741845458),
#  ([[1179, 227], [1199, 227], [1199, 249], [1179, 249]],
#   '=',
#   0.26600063541295427),
#  ([[1205, 208], [1634, 208], [1634, 264], [1205, 264]],
#   'CONFIDENTIAL',
#   0.7561906690448025),
#  ([[293, 377], [331, 377], [331, 419], [293, 419]], '1', 0.9861609279931862),
#  ([[415, 369], [1139, 369], [1139, 435], [415, 435]],
#   'Proposed Title of the Invention',
#   0.984156806954646),
#  ([[430, 478], [1104, 478], [1104, 530], [430, 530]],
#   'Assistive device for Dysarthria (ADD)',
#   0.8782647799621895),
#  ([[1128, 478], [1732, 478], [1732, 526], [1128, 526]],
#   'Wearable device to convert slurred',
#   0.9831102584807279),
#  ([[422, 521], [1433, 521], [1433, 584], [422, 584]],
#   'speech and monitor the severity of Dysarthria in real-time',
#   0.8871268058904319),
#  ([[291, 633], [329, 633], [329, 677], [291, 677]], '2_', 0.3049989671702865),
# ...

# %%
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(IMAGE_PATH)
img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
img = cv2.putText(img,text,top_left, font, 0.5,(255,255,255),2,cv2.LINE_AA)
plt.imshow(img)
plt.show()

# %%
img = cv2.imread(IMAGE_PATH)
spacer = 100
detected_sentence=""
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    detected_sentence+=text+" "
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(20,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=15
    
plt.imshow(img)
plt.show()

# %%
print(detected_sentence)
# Out:
# INVENTIVE DISCLOSURE = CONFIDENTIAL 1 Proposed Title of the Invention Assistive device for Dysarthria (ADD) Wearable device to convert slurred speech and monitor the severity of Dysarthria in real-time 2_ Proposed Abstract of the Invention Dysarthria, is a speech disorder resulting from muscle weakness, paralysis, o neurological impairments affecting articulation, poses significant challenges to effective communication: Patients with   dysarthria often experience  slurred speech, making it difficult to convey their thoughts and needs clearly: This condition profoundly impacts their quality of life, hindering social interactions, and posing obstacles in professional and personal spheres. Our proposed IoT-based assistive device addresses the unique challenges faced by individuals battling dysarthria  By harnessing the power of deep learning frameworks, this device offers real-time  speech   enhancement;  converting slurred speech into articulate and intelligible language. Additionally,
# ...
